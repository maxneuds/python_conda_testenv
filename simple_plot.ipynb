# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 5.0, 0.01)
s = 1 + np.sin(np.pi * t)

fig, ax = plt.subplots(figsize=(10,5))
ax.plot(t, s)

ax.set(xlabel='n x pi', ylabel='y',
       title='Simple Sin')
ax.grid()

plt.show()
